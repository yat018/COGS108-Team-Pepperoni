# %%
import pandas as pd
# read data from web link
r = pd.read_html("https://www.qsrmagazine.com/content/qsr50-2017-top-50-chart")
# create new dataFrame from the first data frame of the list
df = r[0]
df
# Out:
#               0                           1                   2         3  \
# 0   QSR 50 Rank                     Company  Change in Position  Category
# 1             1                 McDonald's*                   -    Burger
# 2             2                 Starbucks*1                   -     Snack
# 3             3                      Subway                   -  Sandwich
# 4             4                     Wendy's                   2    Burger
# 5             5                Burger King*                  -1    Burger
# 6             6                   Taco Bell                  -1    Ethnic
# 7             7             Dunkin' Donuts*                   -     Snack
# 8             8                 Chick-fil-A                   -   Chicken
# 9             9                   Pizza Hut                   -     Pizza
# 10           10                   Domino's*                   1     Pizza
# 11           11                Panera Bread                  -1  Sandwich
# ...
