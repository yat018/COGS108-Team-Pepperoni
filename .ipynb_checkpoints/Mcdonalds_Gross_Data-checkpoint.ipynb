# %%
import pandas as pd
df_list = pd.read_html("https://www.macrotrends.net/stocks/charts/MCD/mcdonalds/gross-profit")
df_yearly = df_list[0]
df_quarterly = df_list[1]

df_yearly
# Out:
#     McDonald's Annual Gross Profit(Millions of US $)  \
# 0                                               2018
# 1                                               2017
# 2                                               2016
# 3                                               2015
# 4                                               2014
# 5                                               2013
# 6                                               2012
# 7                                               2011
# 8                                               2010
# 9                                               2009
# 10                                              2008
# 11                                              2007
# 12                                              2006
# 13                                              2005
#
#    McDonald's Annual Gross Profit(Millions of US $).1
# 0                                             $10,786
# 1                                             $10,621
# ...

# %%
df_quarterly
# Out:
#    McDonald's Quarterly Gross Profit(Millions of US $)  \
# 0                                             Q1 2019
# 1                                             Q4 2018
# 2                                             Q3 2018
# 3                                             Q2 2018
# 4                                             Q1 2018
# 5                                             Q4 2017
# 6                                             Q3 2017
# 7                                             Q2 2017
# 8                                             Q1 2017
# 9                                             Q4 2016
# 10                                            Q3 2016
# 11                                            Q2 2016
# 12                                            Q1 2016
# 13                                            Q4 2015
# 14                                            Q3 2015
# 15                                            Q2 2015
# ...
